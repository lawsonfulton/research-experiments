# %%
from pca_ae_learn import *
# Out:
# Using TensorFlow backend.

# %%
main()
# Out:
# Loading training data...
# Done loading:  0.26187705993652344
# Train on 10000 samples, validate on 1000 samples
# Epoch 1/200
# 10000/10000 [==============================] - 0s - loss: 0.1755 - val_loss: 0.1675
# Epoch 2/200
# 10000/10000 [==============================] - 0s - loss: 0.1679 - val_loss: 0.1571
# Epoch 3/200
# 10000/10000 [==============================] - 0s - loss: 0.1575 - val_loss: 0.1446
# Epoch 4/200
# 10000/10000 [==============================] - 0s - loss: 0.1450 - val_loss: 0.1304
# Epoch 5/200
# 10000/10000 [==============================] - 0s - loss: 0.1307 - val_loss: 0.1146
# Epoch 6/200
# 10000/10000 [==============================] - 0s - loss: 0.1149 - val_loss: 0.0981
# Epoch 7/200
# 10000/10000 [==============================] - 0s - loss: 0.0983 - val_loss: 0.0818
# Epoch 8/200
# 10000/10000 [==============================] - 0s - loss: 0.0820 - val_loss: 0.0661
# Epoch 9/200
# ...
