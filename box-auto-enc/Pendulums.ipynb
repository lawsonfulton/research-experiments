# %%
import pendulums as pd
import matplotlib.pyplot as plt

pd.tests()
# Out:
# Passed.

# %%
print("Generating")
samples = pd.generate_samples(5)
# print(samples)
# print([pd.pendulum_from_vec(s) for s in samples])
x_bounds = [-10, 10]
y_bounds = [-10, 10]
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
ax.set_xlim(x_bounds)
ax.set_ylim(y_bounds)
ax.set_aspect('equal')

print("plotting")
pd.draw_from_samples(ax, samples)
plt.show()
# Out:
# Generating
# plotting

# %%
from pendulum_learn_stacked import *
main()
# Out:
# Generating training data...
# Done. Runtime:  0.47864556312561035
# Train on 1000000 samples, validate on 16384 samples
# Epoch 1/20
# 1000000/1000000 [==============================] - 17s - loss: 0.0081 - val_loss: 0.0022
# Epoch 2/20
# 1000000/1000000 [==============================] - 16s - loss: 0.0017 - val_loss: 0.0012
# Epoch 3/20
# 1000000/1000000 [==============================] - 17s - loss: 7.4931e-04 - val_loss: 8.4648e-04
# Epoch 4/20
# 1000000/1000000 [==============================] - 17s - loss: 7.2464e-04 - val_loss: 8.3659e-04
# Epoch 5/20
# 1000000/1000000 [==============================] - 17s - loss: 7.0253e-04 - val_loss: 9.2189e-04
# Epoch 6/20
# 1000000/1000000 [==============================] - 17s - loss: 7.0429e-04 - val_loss: 8.4043e-04
# Saved at: models/01 52PM August 31 2017.h5
# Total model time:  104.51255869865417
# Predict took:  0.9695940017700195
# Total runtime:  105.96255350112915

# %%
from pendulum_learn import *
ae = load_autoencoder("models/04 31PM August 30 2017.h5")
ae
# Out:
# Loading model...
# Done.
# (<keras.engine.training.Model at 0x7fe43c310cf8>,
# ...
#  <keras.engine.training.Model at 0x7fe43d623400>)

# %%
# import pendulum_sim

# pendulum_sim.simulate("models/pendulum 6e-05 aug 28.h5")
from IPython.core.display import HTML
# %time HTML(animate(*ae).to_html5_video())
# Out:
# loading video
# CPU times: user 14.6 s, sys: 424 ms, total: 15 s
# Wall time: 15.3 s
# <video width="1152" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from IPython.core.display import HTML
# %time HTML(animate(*ae).to_html5_video())
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# loading video
# CPU times: user 10.2 s, sys: 372 ms, total: 10.6 s
# Wall time: 10.9 s
# <video width="1152" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...
